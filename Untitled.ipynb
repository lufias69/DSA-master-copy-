# %%
import dsa2 as ds

# %%
N = 160
L = 1024
p, q, g = ds.generate_params(L, N)
x, y = ds.generate_keys(g, p, q)

text = "sos"
M = str.encode(text, "ascii")
print(M)
r, s = ds.sign(M, p, q, g, x)




m3 = "sos0s"
m3 = str.encode(m3, "ascii")
if ds.verify(m3, r, s, p, q, g, y):
    print('verifikasi berhasil')
else:
    print('verifikasi gagal')
#print(M, r, s, p, q, g, y, x, sep='\n')
print("Pesan :  ", M)
print("r     :  ", r)
print("s     :  ", s)
print("p     :  ", p)
print("q     :  ", q)
print("g     :  ", g)
print("y     :  ", y)
print("x     :  ", x)
# Out:
# b'sos'
# verifikasi gagal
# Pesan :   b'sos'
# r     :   71115015055780289988379122264027154328017785843009776936921362882331523279170
# s     :   53577835229261748365827697158341366675591150059383684572229941331573623987547
# p     :   
# q     :   72422434370555759177316586792784635105960003163414059882984574052862752086179
# g     :   
# ...
